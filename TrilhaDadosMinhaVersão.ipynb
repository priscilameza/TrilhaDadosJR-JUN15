# %% [markdown]
# <a href="https://colab.research.google.com/github/priscilameza/TrilhaDadosJR-JUN15/blob/main/TrilhaDadosMinhaVers%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instalando e importando arquivo

# %%
pip install notebook
# Out:
# ...
# ERROR: Operation cancelled by user

# %%
pip install pandas matplotlib seaborn scikit-learn

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
caminho_arquivo = '/codigocertocoder.csv'
df = pd.read_csv(caminho_arquivo)

# %% [markdown]
# ##Tratamento dos dados

# %%
df.head()
# Out:
#    ID                                  Nome do Curso  Quantidade de Vendas  \
# 0   1             Introdução à Programação em Python                    50
# 1   2             Desenvolvimento Web com HTML e CSS                    30
# 2   3  JavaScript Avançado: Frameworks e Bibliotecas                    20
# 3   4                 Introdução ao Machine Learning                    15
# 4   5        Desenvolvimento Mobile com React Native                    25
#
#    Preço Unitário        Data
# 0            39.9  2023-01-01
# 1            59.9  2023-01-02
# 2            79.9  2023-01-03
# 3            99.9  2023-01-04
# 4            69.9  2023-01-05

# %%
df.dtypes
# Out:
# ID                        int64
# Nome do Curso            object
# Quantidade de Vendas      int64
# Preço Unitário          float64
# Data                     object
# dtype: object

# %%
data_tipe = {
    'ID': str
}
df = pd.read_csv(caminho_arquivo, dtype = data_tipe, parse_dates=['Data'])
df.head()
# Out:
#   ID                                  Nome do Curso  Quantidade de Vendas  \
# 0  1             Introdução à Programação em Python                    50
# 1  2             Desenvolvimento Web com HTML e CSS                    30
# 2  3  JavaScript Avançado: Frameworks e Bibliotecas                    20
# 3  4                 Introdução ao Machine Learning                    15
# 4  5        Desenvolvimento Mobile com React Native                    25
#
#    Preço Unitário       Data
# 0            39.9 2023-01-01
# 1            59.9 2023-01-02
# 2            79.9 2023-01-03
# 3            99.9 2023-01-04
# 4            69.9 2023-01-05

# %%
df.dtypes
# Out:
# ID                              object
# Nome do Curso                   object
# Quantidade de Vendas             int64
# Preço Unitário                 float64
# Data                    datetime64[ns]
# dtype: object

# %% [markdown]
# ## Desafio 1

# %%
df['Total de arrecadação por curso'] = df['Quantidade de Vendas'] * df['Preço Unitário']

df
# Out:
#     ID                                  Nome do Curso  Quantidade de Vendas  \
# 0    1             Introdução à Programação em Python                    50
# 1    2             Desenvolvimento Web com HTML e CSS                    30
# 2    3  JavaScript Avançado: Frameworks e Bibliotecas                    20
# 3    4                 Introdução ao Machine Learning                    15
# 4    5        Desenvolvimento Mobile com React Native                    25
# 5    6                   Arquitetura de Microserviços                    12
# 6    7                     Banco de Dados SQL e NoSQL                    18
# 7    8           Segurança da Informação: Fundamentos                    10
# 8    9                        Cloud Computing com AWS                    22
# 9   10          DevOps: Integração e Entrega Contínua                     8
# 10  11             Desenvolvimento Web com HTML e CSS                    20
# ...

# %%
df['Total de arrecadação por curso'] = df['Total de arrecadação por curso'].astype(int)

# %%
receita_total = df['Total de arrecadação por curso'].astype(float).sum()
print("Receita total:", f"{receita_total:.2f}")
# Out:
# Receita total: 32735.10

# %% [markdown]
# ##Desafio 2

# %%
df.describe()
# Out:
#        Quantidade de Vendas  Preço Unitário                 Data  \
# count             25.000000       25.000000                   25
# mean              17.960000       83.900000  2023-01-13 00:00:00
# min                5.000000       39.900000  2023-01-01 00:00:00
# 25%               10.000000       69.900000  2023-01-07 00:00:00
# 50%               15.000000       79.900000  2023-01-13 00:00:00
# 75%               20.000000       99.900000  2023-01-19 00:00:00
# max               50.000000      119.900000  2023-01-25 00:00:00
# std               10.921996       21.984843                  NaN
#
#        Total de arrecadação por curso
# count                       25.000000
# mean                      1309.404000
# min                        549.500000
# 25%                        999.000000
# 50%                       1258.200000
# 75%                       1498.500000
# max                       2197.800000
# std                        412.195665

# %%
maior_venda = df[df['Quantidade de Vendas'] == 50]
maior_venda
# Out:
#   ID                       Nome do Curso  Quantidade de Vendas  \
# 0  1  Introdução à Programação em Python                    50
#
#    Preço Unitário       Data  Total de arrecadação por curso
# 0            39.9 2023-01-01                          1995.0

# %%
maior_venda = df[df['Quantidade de Vendas'] >= 50]
maior_venda
# Out:
#   ID                       Nome do Curso  Quantidade de Vendas  \
# 0  1  Introdução à Programação em Python                    50
#
#    Preço Unitário       Data  Total de arrecadação por curso
# 0            39.9 2023-01-01                          1995.0

# %% [markdown]
# ##Desafio 3

# %%
df
# Out:
#     ID                                  Nome do Curso  Quantidade de Vendas  \
# 0    1             Introdução à Programação em Python                    50
# 1    2             Desenvolvimento Web com HTML e CSS                    30
# 2    3  JavaScript Avançado: Frameworks e Bibliotecas                    20
# 3    4                 Introdução ao Machine Learning                    15
# 4    5        Desenvolvimento Mobile com React Native                    25
# 5    6                   Arquitetura de Microserviços                    12
# 6    7                     Banco de Dados SQL e NoSQL                    18
# 7    8           Segurança da Informação: Fundamentos                    10
# 8    9                        Cloud Computing com AWS                    22
# 9   10          DevOps: Integração e Entrega Contínua                     8
# 10  11             Desenvolvimento Web com HTML e CSS                    20
# ...

# %%
#grafico 1
df['Total de arrecadação por curso'].plot(kind='bar', title='Valor total vendido por dia')
plt.xlabel('Data')
plt.ylabel= ('Total de arrecadação por curso')
plt.show()

# %%
#gráfico 2
df['Quantidade de Vendas'].plot(kind='line', title='Quantidade vendida por dia')
plt.xlabel('Data')
plt.ylabel= ('Quantidade de Vendas')
plt.grid(True)
plt.show()

# %%
#grafico 3
df.plot.scatter(x='Quantidade de Vendas', y='Total de arrecadação por curso', title='Relação entre Quantidade de Vendas e Total de Arrecadação por Curso')
plt.xlabel('Quantidade de Vendas')
plt.grid(True)
plt.show()
